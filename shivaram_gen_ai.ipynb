# %% [markdown]
# <a href="https://colab.research.google.com/github/Shiva3124/Image-to-Audio-Generator/blob/main/shivaram_gen_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gtts

# %%
from gtts import gTTS
import IPython.display as display

# %%
text = input("Enter the text you want to convert to audio:\n")
# Out:
# Enter the text you want to convert to audio:
# Hello! Welcome to my AI project. This is a text-to-audio generator.”

# %%
tts = gTTS(text)
tts.save("output_audio.mp3")
print("✅ Audio generated successfully!")
# Out:
# ✅ Audio generated successfully!

# %%
display.Audio("output_audio.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
